# %%
from IPython.core.debugger import set_trace

set_trace()


def do_sth(x, y):
    print(x)
    print(y)
    z = x + y
    return z


x = 3
y = 5

z1 = do_sth(x, y)
print(z1)

z2 = do_sth(x, y)
print(z2)

z3 = z1 + z2
print(z3)
# Out:
# --Return--
# None
# > <ipython-input-1-33365a964155>(3)<module>()
#       1 from IPython.core.debugger import set_trace
#       2
# ----> 3 set_trace()
#       4
#       5
#
# ipdb> b 13
# Breakpoint 1 at <ipython-input-1-33365a964155>:13
# ipdb> c
# None
# > <ipython-input-1-33365a964155>(13)<module>()
#      11
#      12
# 1--> 13 x = 3
#      14 y = 5
#      15
#
# ipdb> p x
# *** NameError: name 'x' is not defined
# ipdb> n
# --Return--
# None
# > <ipython-input-1-33365a964155>(13)<module>()
#      11
#      12
# 1--> 13 x = 3
#      14 y = 5
#      15
#
# ipdb> p x
# 3
# ipdb> b 16
# Breakpoint 2 at <ipython-input-1-33365a964155>:16
# ipdb> b
# Num Type         Disp Enb   Where
# 1   breakpoint   keep yes   at <ipython-input-1-33365a964155>:13
# 	breakpoint already hit 1 time
# 2   breakpoint   keep yes   at <ipython-input-1-33365a964155>:16
# ipdb> c
# None
# > <ipython-input-1-33365a964155>(16)<module>()
#      14 y = 5
#      15
# 2--> 16 z1 = do_sth(x, y)
# ...
