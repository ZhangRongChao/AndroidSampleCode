# %%
import pdb

pdb.set_trace()


def do_sth(x, y):
    print(x)
    print(y)
    z = x + y
    return z


x = 3
y = 5

z1 = do_sth(x, y)
print(z1)

z2 = do_sth(x, y)
print(z2)

z3 = z1 + z2
print(z3)
# Out:
# --Return--
# > <ipython-input-1-e262c99bd424>(3)<module>()->None
# -> pdb.set_trace()
# (Pdb) b 13
# Breakpoint 1 at <ipython-input-1-e262c99bd424>:13
# (Pdb) c
# > <ipython-input-1-e262c99bd424>(13)<module>()->None
# -> x = 3
# (Pdb) p x
# *** NameError: name 'x' is not defined
# (Pdb) n
# --Return--
# > <ipython-input-1-e262c99bd424>(13)<module>()->None
# -> x = 3
# (Pdb) p x
# 3
# (Pdb) b 16
# Breakpoint 2 at <ipython-input-1-e262c99bd424>:16
# (Pdb) b
# Num Type         Disp Enb   Where
# 1   breakpoint   keep yes   at <ipython-input-1-e262c99bd424>:13
# 	breakpoint already hit 1 time
# 2   breakpoint   keep yes   at <ipython-input-1-e262c99bd424>:16
# (Pdb) c
# > <ipython-input-1-e262c99bd424>(16)<module>()->None
# -> z1 = do_sth(x, y)
# (Pdb) n
# 3
# 5
# --Return--
# > <ipython-input-1-e262c99bd424>(16)<module>()->None
# -> z1 = do_sth(x, y)
# (Pdb) p z1
# 8
# (Pdb) b 19
# Breakpoint 3 at <ipython-input-1-e262c99bd424>:19
# (Pdb) c
# 8
# ...
